# %%
import pandas as pd

# %%
gol = pd.read_csv('/content/drive/MyDrive/MC536 - Grupo GOLDB/csv_fengda/gol.csv')

# %%
gol.columns = ['idGol', 'idPartida', 'idTime', 'idJogadorGol', 'idJogadorAssistencia', 'tempo', 'acrescimo']
gol
# Out:
#      idGol  idPartida  idTime  ...  idJogadorAssistencia  tempo  acrescimo
# 0        1      94471     134  ...               10150.0      3        NaN
# 1        2      94471     134  ...                   NaN     45        NaN
# 2        3      94471     134  ...                   NaN     66        NaN
# 3        4      94471     134  ...               10143.0     86        NaN
# 4        5      94471     133  ...               10574.0     89        NaN
# ..     ...        ...     ...  ...                   ...    ...        ...
# 870    871      94849     128  ...                   NaN     23        NaN
# 871    872      94849     128  ...                2454.0     63        NaN
# 872    873      94849     128  ...                9988.0     85        NaN
# 873    874      94850     133  ...                   NaN     84        NaN
# 874    875      94850     132  ...               53958.0     90        3.0
#
# [875 rows x 7 columns]

# %%
gol.to_csv('/content/drive/MyDrive/MC536 - Grupo GOLDB/csv_fengda/gol.csv', index=False)

# %%
jogadores = pd.read_csv('/content/drive/MyDrive/MC536 - Grupo GOLDB/csv_fengda/jogadores.csv')
jogadores = jogadores.rename(columns=lambda x: x.replace(' ', ''))
jogadores
# Out:
#      Iddojogador  Nomedojogador  ...  Iddotimerodada37  Iddotimerodada38
# 0          10112         Santos  ...                -1                -1
# 1          10123       Jonathan  ...                -1                -1
# 2          10121  Thiago Heleno  ...               134                -1
# 3          10124    Léo Pereira  ...                -1                -1
# 4          10122     Renan Lodi  ...                -1                -1
# ..           ...            ...  ...               ...               ...
# 617       167010         Frizzo  ...                -1               130
# 618        69198        Patrick  ...                -1               130
# 619        80536         Isaque  ...                -1               130
# 620       106510       Ferreira  ...                -1               130
# 621         9900         Maicon  ...                -1              1062
#
# [622 rows x 40 columns]

# %%
jogadores.to_csv('/content/drive/MyDrive/MC536 - Grupo GOLDB/csv_fengda/jogadores.csv', index=False)

# %%
subs = pd.read_csv('/content/drive/MyDrive/MC536 - Grupo GOLDB/csv_fengda/subst.csv')
subs = subs.rename(columns=lambda x: x.replace(' ', ''))
subs
# Out:
#       Idsubstituicao  Idpartida  Idtime  ...  IdJogadorSubstituto  Tempo  Acrescimo
# 0                  1      94471     134  ...                10128     34        NaN
# 1                  2      94471     133  ...                10575     58        NaN
# 2                  3      94471     133  ...                10570     58        NaN
# 3                  4      94471     133  ...                10573     68        NaN
# 4                  5      94471     134  ...                10142     69        NaN
# ...              ...        ...     ...  ...                  ...    ...        ...
# 2241            2242      94850     133  ...               143367     57        NaN
# 2242            2243      94850     132  ...                53958     63        NaN
# 2243            2244      94850     133  ...                10564     68        NaN
# 2244            2245      94850     132  ...                10208     72        NaN
# ...

# %%
subs.to_csv('/content/drive/MyDrive/MC536 - Grupo GOLDB/csv_fengda/subst.csv', index=False)

# %%
tecnicos = pd.read_csv('/content/drive/MyDrive/MC536 - Grupo GOLDB/csv_fengda/tecnicos.csv')
tecnicos = tecnicos.rename(columns=lambda x: x.replace(' ', ''))
tecnicos
# Out:
#                     Nome  Iddotimerodada1  ...  Iddotimerodada37  Iddotimerodada38
# 0            Tiago Nunes              134  ...                -1                -1
# 1       Marcos Valadares              133  ...                -1                -1
# 2        Rodrigo Santana             1062  ...                -1                -1
# 3                Geninho              145  ...                -1                -1
# 4          Roger Machado              118  ...               118               118
# 5          Fábio Carille              131  ...                -1                -1
# 6       Enderson Moreira              129  ...                -1                -1
# 7           Marcelo Cabo              150  ...                -1                -1
# 8             Ney Franco              132  ...               151               151
# 9         Odair Hellmann              119  ...                -1                -1
# ...

# %%
tecnicos.to_csv('/content/drive/MyDrive/MC536 - Grupo GOLDB/csv_fengda/tecnicos.csv', index=False)
